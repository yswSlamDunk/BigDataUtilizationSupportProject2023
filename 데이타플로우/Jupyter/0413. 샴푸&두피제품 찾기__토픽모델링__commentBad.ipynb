# %%
import os
import pandas as pd
import numpy as np
import time

import pyLDAvis
import pyLDAvis.gensim_models as pyGensim
import pickle

pyLDAvis.enable_notebook()

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_6.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# /home/yooseungwoo/anaconda3/lib/python3.9/site-packages/gensim/matutils.py:22: DeprecationWarning: Please use `triu` from the `scipy.linalg` namespace, the `scipy.linalg.special_matrices` namespace is deprecated.
#   from scipy.linalg.special_matrices import triu
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115838429288996540058" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_7.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115838449443488637484" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_8.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el12518140711583843712550573516" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_9.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115838462881699273543" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_10.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115838437128179726579" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_11.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407112107656648513524775" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_12.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835616488651151642" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_13.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115838440485117612892" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_14.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835620963859123596" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_15.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835616484335448281" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_16.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835618725260433292" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_17.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835613124176392112" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_18.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835620961790804159" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_19.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835600807964701684" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
with open(file = '../Result/LDA/샴푸&두피케어_샴푸&두피제품 찾기/commentBad/topicNum_20.pickle', mode = 'rb') as f:
    lda = pickle.load(f)
    ldaModel = lda[0]
    dictionary = lda[1]
    corpus = lda[2]

    vis = pyGensim.prepare(ldaModel, corpus, dictionary)

pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el125181407115835628804604901864" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...
