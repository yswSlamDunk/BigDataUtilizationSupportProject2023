# %%
from pandas import read_csv as reader
import pandas as pd

# %%
df = pd.read_csv('good_talmo.csv',encoding='utf-8')
df['Post Date'] = pd.to_datetime(df['Post Date'])
df.to_csv('good_talmo.csv',index=False)
df
# Out:
#                                              Title        Author  \
# 0       10년넘게 활동한 대다모 잊고 살다가 5년만에 온 것이면 어느정도 성공이죠?         vvip2
# 1                       성공스토리 게시판에 올려도되나 모르겠네요 ㅋㅋㅋ          부산시민
# 2                         프로페시아 17년부터 복용 22년 현재 후기     자라나라자라나라얍
# 3                              엑소좀+보톡스 탈모치료 후기입니다.      Jack0911
# 4                           모낭주사 + 프로페시아 1년 6개월 경과           앙더리
# ..                                             ...           ...
# 364              최종 발모 성공기 + 내가 터득한 가장 확실한 발모 비법들.  가을날씨는 좋은데,,,
# 365                              요한초(세인트존스워트) 보세요.         감사합니다
# 366                            베를린천사의 무모증 탈출기...ㅋㅋ         베를린천사
# 367                      탈모 탈출이 아니라면 탈모 초월이고 싶다!!!           프리맨
# 368  가발사건에 대해 그린헤어 운영자 대탈출님이 회원들께 싸이트에 올린 글입니다.(펌)           열받아
#
#                     Post Date  \
# 0   2023-06-07 14:12:32+09:00
# 1   2023-02-11 21:33:46+09:00
# 2   2022-06-07 11:21:27+09:00
# 3   2022-01-02 21:14:27+09:00
# ...
