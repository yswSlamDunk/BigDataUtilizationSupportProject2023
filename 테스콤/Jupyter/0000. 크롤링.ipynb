# %%
import pandas as pd

# %%
df = pd.read_csv('urls.csv')

# %%
df['Category'] = df['Category'].apply(lambda x : eval(x))
# df = df[df['Category'].apply(lambda x : '6G' in x)]

# %%
len(df)
# Out:
# 4540

# %%
df[df['URL'].apply(lambda x: 'rcrtv' in str(x))]
# Out:
#                                                     URL      Category
# 703       https://www.rcrwireless.com/rcrtv/lg-g5-tag31          [6G]
# 735   https://www.rcrwireless.com/rcrtv/gigs-day-lif...          [6G]
# 921   https://www.rcrwireless.com/rcrtv/5g-standards...        [MIMO]
# 929   https://www.rcrwireless.com/rcrtv/whats-next-b...        [MIMO]
# 942   https://www.rcrwireless.com/rcrtv/galtronics-m...        [MIMO]
# 1757  https://www.rcrwireless.com/rcrtv/sprint-looks...        [MIMO]
# 1768  https://www.rcrwireless.com/rcrtv/sprint-tech-...        [MIMO]
# 1896  https://www.rcrwireless.com/rcrtv/linknyc-laun...        [MIMO]
# 1906  https://www.rcrwireless.com/rcrtv/ieee-globeco...        [MIMO]
# 1922  https://www.rcrwireless.com/rcrtv/digs-inside-...        [MIMO]
# 1932  https://www.rcrwireless.com/rcrtv/how-it-works...        [MIMO]
# 1945  https://www.rcrwireless.com/rcrtv/national-ins...        [MIMO]
# ...

# %%
df = pd.read_csv('rc.csv')
df['Author'].unique()
# Out:
# array(['Juan Pedro Tomás', 'Kelly Hill',
#        'RCR Wireless News & Qualcomm (Sponsored)',
#        'Catherine Sbeglia Nin', 'James Blackman', 'Jeff Kagan',
#        'RCR Wireless News', 'Sean Kinney, Editor in Chief',
#        'RCR Wireless News and Rohde & Schwarz (Sponsored)',
#        'Keith Mallinson', 'rcrwireless', 'Prakash Sangam', 'Reader Forum',
#        'Susan Rambo', 'Martha DeGrasse', 'rcrwirelessadmin',
#        'Sylvie Barak',
#        'Richard Barnett, Chief Marketing Officer, SupplyFrame',
#        'Jon Arnold, Principal, J Arnold & Associates',
#        'RCR Wireless News and Broadcom (Sponsored)',
#        'Dimitris Mavrakis, Sr. Director, ABI Research',
#        'Dimitris Mavrakis, Sr. Research Director, ABI Research',
#        'David Vondran, Wireless Product Manager, Teradyne and Rodrigo Carrillo-Ramirez, Millimeter Wave Engineering Manager, Teradyne',
#        'Deepak Das, Vice President of Solutions, Federated Wireless',
#        'ZTE (Sponsored)',
# ...

# %%
df['Category']
# Out:
# 0                   [6G]
# 1                   [6G]
# 2       [6G, Automotive]
# 3       [6G, Automotive]
# 4                   [6G]
#               ...
# 4478        [Automotive]
# 4479        [Automotive]
# 4480        [Automotive]
# 4481        [Automotive]
# 4482        [Automotive]
# Name: Category, Length: 4483, dtype: object

# %%
import pandas as pd
df = pd.read_csv('tmp.csv')
df.head()
# Out:
#     Post ID                                               Href  \
# 0  149268.0  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4  149219.0  https://cafe.naver.com/ArticleRead.nhn?clubid=...
#
#                Title Author            Timestamp  \
# 0   단풍나무가 아퍼요. 도와주세요    기리박  2023-09-11 14:28:00
# 1                NaN    NaN                  NaN
# 2                NaN    NaN                  NaN
# 3                NaN    NaN                  NaN
# 4  불쑥불쑥한 백철쭉을 다듬어줄까요   기적소리  2023-09-07 16:45:00
#
#                                                 Text  \
# 0                다른 단풍나무는 안그런데 갑자기 아프네요.\n자문좀 부탁드려요.
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...
